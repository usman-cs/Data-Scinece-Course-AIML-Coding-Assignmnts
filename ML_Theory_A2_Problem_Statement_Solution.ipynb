# %% [markdown]
# ## Probability Calculation

# %% [markdown]
# ## DataSet https://drive.google.com/file/d/1EjxpErOL2GtXCIyvz2xxnJPy5PO9wSZO/view?usp=sharing

# %%
import pandas as pd

# %%
data = pd.read_csv("mushrooms.csv")

# %%
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# Compute the following Probabilities

# %% [markdown]
# \begin{equation}
# P(Cap-shape \cap Cap-surface | Class = p)\\[10pt]
# P(Cap-shape \cap Cap-surface | Class = e)\\[10pt]
# P(Cap-shape \cap Cap-surface \cap ......\cap habitat | Class = p)\\[10pt]
# \end{equation}

# %% [markdown]
# ## 1
# \begin{equation}
# P(Cap-shape \cap Cap-surface | Class = p)\\[10pt]
# \end{equation}
# \begin{equation}
# P(Cap-shape \cap Cap-surface | Class = p)  = \frac{Joint \,\, Probability \,\, Of \,\, Cap-Shape \,\, and \,\, Cap-surface}{Probability \,\, of \,\, p \,\, class}
# \end{equation}

# %%
for capShape in data['cap-shape'].unique():
    for capSurface in data['cap-surface'].unique():
        conditionalProbability = data[(data['cap-shape']==capShape) & (data['cap-surface']==capSurface) & (data['class']=='p')].shape[0]/data[data['class']==cls].shape[0]
        print(f"P(cap-shape = {capShape} and cap-surace = {capSurface} | class = p) = {conditionalProbability}")
# Out:
# P(cap-shape = x and cap-surace = s | class = p) = 0.14068441064638784
# P(cap-shape = x and cap-surace = y | class = p) = 0.1644486692015209
# P(cap-shape = x and cap-surace = f | class = p) = 0.10076045627376426
# P(cap-shape = x and cap-surace = g | class = p) = 0.0
# P(cap-shape = b and cap-surace = s | class = p) = 0.0042775665399239545
# P(cap-shape = b and cap-surace = y | class = p) = 0.00594106463878327
# P(cap-shape = b and cap-surace = f | class = p) = 0.0009505703422053232
# P(cap-shape = b and cap-surace = g | class = p) = 0.0002376425855513308
# P(cap-shape = s and cap-surace = s | class = p) = 0.0
# P(cap-shape = s and cap-surace = y | class = p) = 0.0
# P(cap-shape = s and cap-surace = f | class = p) = 0.0
# P(cap-shape = s and cap-surace = g | class = p) = 0.0
# P(cap-shape = f and cap-surace = s | class = p) = 0.12214828897338403
# P(cap-shape = f and cap-surace = y | class = p) = 0.16943916349809887
# ...

# %% [markdown]
# ## 2
# \begin{equation}
# P(Cap-shape \cap Cap-surface | Class = e)\\[10pt]
# \end{equation}
# \begin{equation}
# P(Cap-shape \cap Cap-surface | Class = p)  = \frac{Joint \,\, Probability \,\, Of \,\, Cap-Shape \,\, and \,\, Cap-surface}{Probability \,\, of \,\, e \,\, class}
# \end{equation}

# %%
for capShape in data['cap-shape'].unique():
    for capSurface in data['cap-surface'].unique():
        conditionalProbability = data[(data['cap-shape']==capShape) & (data['cap-surface']==capSurface) & (data['class']=='e')].shape[0]/data[data['class']==cls].shape[0]
        print(f"P(cap-shape = {capShape} and cap-surace = {capSurface} | class = e) = {conditionalProbability}")
# Out:
# P(cap-shape = x and cap-surace = s | class = e) = 0.11454372623574144
# P(cap-shape = x and cap-surace = y | class = e) = 0.17347908745247148
# P(cap-shape = x and cap-surace = f | class = e) = 0.17490494296577946
# P(cap-shape = x and cap-surace = g | class = e) = 0.0
# P(cap-shape = b and cap-surace = s | class = e) = 0.05370722433460076
# P(cap-shape = b and cap-surace = y | class = e) = 0.030893536121673004
# P(cap-shape = b and cap-surace = f | class = e) = 0.011406844106463879
# P(cap-shape = b and cap-surace = g | class = e) = 0.0
# P(cap-shape = s and cap-surace = s | class = e) = 0.0
# P(cap-shape = s and cap-surace = y | class = e) = 0.0
# P(cap-shape = s and cap-surace = f | class = e) = 0.0076045627376425855
# P(cap-shape = s and cap-surace = g | class = e) = 0.0
# P(cap-shape = f and cap-surace = s | class = e) = 0.07271863117870722
# P(cap-shape = f and cap-surace = y | class = e) = 0.14306083650190113
# ...
